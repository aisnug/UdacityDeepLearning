# %% [markdown]
# SIGMOID

# %%
import numpy as np

# %%
x1, x2 = -4, 5
sigmoid = 1/(1 + np.exp(-(4*x1 + 5*x2 - 9 ))) 
sigmoid
# Out:
# 0.5

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
sigmoid(np.array([2, 2.3]))
# Out:
# array([0.88079708, 0.90887704])

# %% [markdown]
# SOFTMAX

# %%
L=[1, 2, 3, 4]
softmax = np.exp(L)/np.sum(np.exp(L))
softmax
# Out:
# array([0.0320586 , 0.08714432, 0.23688282, 0.64391426])

# %% [markdown]
# CROSS ENTROPY

# %%
Y=[0, 0.5, 1]
p = [0.2, 0.9, 0.8]

-sum([Y[i]*np.log(p[i])+(1-Y[i])*np.log(1-p[i]) for i in range(len(Y))])
# Out:
# 1.6502599069543555

# %%
w1, w2, b = 2, 6, -2
sigmoid(w1*0.4+w2*0.6+b)
# Out:
# 0.9168273035060777

# %%
w1, w2, b = 3, 5, -2.2
sigmoid(w1*0.4+w2*0.6+b)
# Out:
# 0.8807970779778823

# %%
x = np.array([0.5, 1, 2])
w = np.array([[1, 2], [2, 3], [3, 2]])

# %%
print(x.shape, w.shape)
# Out:
# (3,) (3, 2)

# %%
np.dot(w, x).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-1bd714b7a65c> in <module>
# ----> 1 np.dot(w, x).shape
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (3,2) and (3,) not aligned: 2 (dim 1) != 3 (dim 0)

# %%
np.array([1, 2]).shape
# Out:
# (2,)

# %%
np.dot(np.array([1, 2]), np.array([[1, 2]]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-5d7005c87a6e> in <module>
# ----> 1 np.dot(np.array([1, 2]), np.array([[1, 2]]))
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,) and (1,2) not aligned: 2 (dim 0) != 1 (dim 0)
